# %% [markdown]
# # 🪶 Compilador do APK 'Voo de Ícaro' (Google Colab)
# Este script automatiza a geração do seu APK para o concurso. Siga os passos abaixo:
#
# 1. **Upload:** Clique no ícone de pasta à esquerda e faça o upload do arquivo `mobile_app.zip` que você baixou do Manus.
# 2. **Executar:** Clique no botão de 'Play' em cada célula abaixo em ordem.
# 3. **Download:** Ao final, o arquivo `.apk` aparecerá na pasta à esquerda para você baixar.

# %%
# 1. Instalar dependências do sistema
# !sudo apt-get update
# !sudo apt-get install -y git zip unzip openjdk-17-jdk python3-pip autoconf libtool pkg-config zlib1g-dev libncurses5-dev libncursesw5-dev libtinfo5 cmake libffi-dev libssl-dev
# !pip install --upgrade buildozer Cython virtualenv

# %%
# 2. Extrair o código do projeto
# !unzip mobile_app.zip -d project_folder
# %cd project_folder

# %%
# 3. Iniciar a compilação (Pode levar 15-20 minutos)
# Responda 'y' se ele pedir para aceitar licenças do Android SDK
# !buildozer -v android debug

# %% [markdown]
# ### ✅ Pronto!
# O seu APK estará na pasta `bin/`. Basta baixar e instalar no seu celular!
